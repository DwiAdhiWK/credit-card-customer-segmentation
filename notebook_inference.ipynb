# %% [markdown]
# # Model Inference

# %% [markdown]
# Bagian ini saya akan melakukan inference untuk memprediksi user ini masuk ke kluster apa.

# %% [markdown]
# # Import Libraries

# %%
import pickle
import pandas as pd

# %%
with open('model.pkl', 'rb') as file:
    model = pickle.load(file)

# %% [markdown]
# Load pipeline nya ke varible model

# %%
model
# Out:
# Pipeline(steps=[('transform',
#                  Pipeline(steps=[('capping',
#                                   Winsorizer(capping_method='iqr', fold=3,
#                                              tail='both',
#                                              variables=['PURCHASES',
#                                                         'ONEOFF_PURCHASES',
#                                                         'INSTALLMENTS_PURCHASES',
#                                                         'CASH_ADVANCE',
#                                                         'CASH_ADVANCE_TRX',
#                                                         'PURCHASES_TRX',
#                                                         'PAYMENTS',
#                                                         'MINIMUM_PAYMENTS'])),
#                                  ('scaling', StandardScaler()),
#                                  ('reducing', PCA(n_components=11))])),
# ...

# %% [markdown]
# Berikut bentuk pipeline nya.

# %%
data_inf = {
    'CUST_ID':9999,
    'BALANCE':2000,
    'BALANCE_FREQUENCY': 0.5,
    'PURCHASES': 1000,
    'ONEOFF_PURCHASES': 600,
    'INSTALLMENTS_PURCHASES': 800,
    'CASH_ADVANCE':	500,
    'PURCHASES_FREQUENCY':0.5,
    'ONEOFF_PURCHASES_FREQUENCY':0.5,
    'PURCHASES_INSTALLMENTS_FREQUENCY':0.7,
    'CASH_ADVANCE_FREQUENCY':0.3,
    'CASH_ADVANCE_TRX':3,
    'PURCHASES_TRX':20,
    'CREDIT_LIMIT':5000,
    'PAYMENTS':800,
    'MINIMUM_PAYMENTS':500,
    'PRC_FULL_PAYMENT':0.2,
    'TENURE': 12
}
df_inf = pd.DataFrame([data_inf])
df_inf
# Out:
#    CUST_ID  BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     9999     2000                0.5       1000               600
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                     800           500                  0.5
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.5                               0.7
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                     0.3                 3             20          5000
#
#    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0       800               500               0.2      12

# %% [markdown]
# Data inference saya ubah dari dictionary menjadi dataframe df_inf

# %%
df_inf = df_inf.drop(columns='CUST_ID')
df_inf
# Out:
#    BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     2000                0.5       1000               600
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                     800           500                  0.5
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.5                               0.7
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                     0.3                 3             20          5000
#
#    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0       800               500               0.2      12

# %% [markdown]
# Sama seperti notebook sebelum nya kolom CUST_ID di drop karena unique identifier tidak memberikan pola.

# %%
model.predict(df_inf)
# Out:
# array([0], dtype=int32)

# %% [markdown]
# Bedasarkan hasil prediksi user kartu kredit ini masuk dalam cluster 0.
